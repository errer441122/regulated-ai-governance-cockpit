# %% [markdown]
# # AI Data and Agentic Readiness Analysis
#
# Notebook outline for reviewing simulated workflow candidates across public-sector, financial-services, industrial, research, and AI Factory-style scenarios.

# %%
import pandas as pd

df = pd.read_csv('../data/workflow_candidates.csv')
df.head()

# %%
score_columns = ['metadata_quality', 'data_governance', 'stakeholder_clarity', 'data_engineering_maturity', 'reporting_value', 'ai_workload_fit']
df.groupby('sector')[score_columns].mean().round(2)

# %%
high_sensitivity = df[df['data_sensitivity'].eq('high')]
high_sensitivity[['workflow_id', 'organization', 'data_governance', 'metadata_quality', 'agentic_use_approved']]

# %% [markdown]
# ## Interview Discussion
#
# - Which workflows are closest to controlled pilot readiness?
# - Which blockers should stop an agentic workflow?
# - What metadata would be needed before using real data?
# - How would this become a Power BI dashboard, data mart, or AI Factory intake workflow?
