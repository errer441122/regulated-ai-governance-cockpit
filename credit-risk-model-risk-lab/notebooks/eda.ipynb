# %% [markdown]
# # GiveMeSomeCredit EDA Outline
#
# This notebook is an outline for reviewer navigation. The executable pipeline is in `src/fetch_data.py`, `src/train.py`, and `src/evaluate.py`.

# %% [markdown]
# Recommended EDA checks: target event rate, missingness in `MonthlyIncome` and `NumberOfDependents`, delinquency count distributions, score distribution, calibration bins, and train/test PSI.
